# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC 
from sklearn import svm
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/monikadvorackova/Machinelearning/Basic_neural_network.ipynb buňka 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/monikadvorackova/Machinelearning/Basic_neural_network.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/monikadvorackova/Machinelearning/Basic_neural_network.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/Users/monikadvorackova/Machinelearning/Basic_neural_network.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# /Users/monikadvorackova/tensorflow-machinelearing_1/env/bin/python

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2023-10-06 20:14:31.167998: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.12.0

# %%
import tensorflow as tf 
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

#simplest possible neural network - one layer, one neuron
#sequential = defines layers, inside sequential - define what each layer look like
#using the keras - define what the layer look like, dense means a set of fully densely connected
#neurons - every neuron is connected to other neuron 
model = Sequential([Dense(units=1, input_shape=[1])])
#how good the quess is - loss function
#sgd = optimizer - stochastic gradient descent - complex math function that, when given the values
# the previous guess, and the result of calculating the errors on that guess, can then generate another one
# the job of the optimizer is to minimize the loss -> bring guessed formula closer and closer
model.compile(optimizer='sgd', loss='mean_squared_error')

#input data, format that the layers expect -> numpy array
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

#fit the Xs to the Ys and try it 500 times
model.fit(xs, ys, epochs=500)
#predict Y when X is 10 - value close to 19
print(model.predict([10.0]))
# Out:
# 2023-10-06 20:16:36.021364: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-10-06 20:16:36.022576: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/500
# 2023-10-06 20:16:37.346520: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-06 20:16:37.399725: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignVariableOp.
# 1/1 [==============================] - 2s 2s/step - loss: 18.5089
# Epoch 2/500
# ...

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

#variale called l0 to hold dense layer, after the network finishes learning, I can print
#out the values or weight I learned
l0 = Dense(units=1, input_shape=[1])
model = Sequential([l0])
model.compile(optimizer = 'sgd', loss = 'mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
xy = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, xy, epochs = 500)

print(model.predict([10.0]))
print('Here is what I learned: {}'.format(l0.get_weights()))
# Out:
# Epoch 1/500
# 2023-10-06 20:30:14.638175: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-10-06 20:30:14.678585: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignVariableOp.
# 1/1 [==============================] - 0s 435ms/step - loss: 0.6249
# Epoch 2/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6064
# Epoch 3/500
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5895
# Epoch 4/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5738
# Epoch 5/500
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5593
# Epoch 6/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5456
# Epoch 7/500
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5327
# Epoch 8/500
# ...
